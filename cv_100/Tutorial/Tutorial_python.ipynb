# %% [markdown]
# <a href="https://colab.research.google.com/github/yoyoyo-yo/Gasyori100knock/blob/master/Tutorial/Tutorial_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial Python
#
# C++でやりたい人はこっち〜〜
#
# https://github.com/yoyoyo-yo/Gasyori100knock/blob/master/Tutorial/README_opencv_c_install.md
#
# JavaScriptでやりたい人はこっち〜〜
#
# https://github.com/yoyoyo-yo/Gasyori100knock/blob/master/Tutorial/README_javascript.md
#
# ここでは画像処理におけるnumpyの基本的な使い方をいくつか紹介する。
#
# numpyとはpyhtonで用意されたパッケージ(Cでいうライブラリのようなもの)の一種で、行列演算などが得意。
#
# また、画像処理ではOpenCVというライブラリがあり、様々な処理をAPIにしてる。https://opencv.org/
#
# この問題では、numpyをいじって、OpenCVの処理を自分の手で実現することが目標。
#
# pythonでのOpenCVはnumpyをベースとしているため、numpyがいじれる=OpenCVもいじれる　ことになる。
#
# jupyter notebookがおすすめ！ もしくはGoogleColab https://colab.research.google.com/notebooks/intro.ipynb?hl=ja

# %% [markdown]
# # 画像処理の基本
#
# PCやスマホ上で画像は数値の配列（行列）として存在している。
#
# 見た目はモノや風景に見えるが、その実態は数値が行と列とチャンネルの3方向に並んだ数値の集合だ。1マスをピクセル(pixel)や画素と呼ぶ。
#
# <img src="https://github.com/yoyoyo-yo/Gasyori100knock/blob/master/Tutorial/assets/img_basic1.png?raw=1" height=300>
#
# 画像の色の表現にはRGB(Red, Green, Blue)の3つの組み合わせが使われている。RGBは行と列とは別方向に並んだ軸であり、基本的にはRGBがチャンネル方向で表現される
#
# この数値は 0から255の256の数値で大小が表現され、値が大きいほどその色味が強い。たとえば (R, G, B) = (255, 10, 100)であれば、赤味が最も強く、緑味が最も弱い色になる。RGBをそれぞれ0から255に変化させた色合いが下図となる。
#
# <img src="https://github.com/yoyoyo-yo/Gasyori100knock/blob/master/Tutorial/assets/img_basic2.png?raw=1" height=100>
#
# 画像処理では、ピクセルの値を操作する処理である。この時の操作とは、たとえば、隣り合っているピクセルの差分をとったりして、輪郭をとったりすることを示す。
#
# <img src="https://github.com/yoyoyo-yo/Gasyori100knock/blob/master/Tutorial/assets/img_basic3.png?raw=1" height=150>

# %%
# !apt update
# Out:
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 http://security.debian.org/debian-security buster/updates InRelease
# Hit:3 http://deb.debian.org/debian buster-updates InRelease
# Hit:4 https://deb.nodesource.com/node_12.x buster InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# All packages are up to date.

# %%
# !apt-get install -y libgl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libdrm-amdgpu1 libdrm-common libdrm-dev libdrm-etnaviv1 libdrm-freedreno1
#   libdrm-nouveau2 libdrm-radeon1 libdrm-tegra0 libdrm2 libegl-mesa0 libegl1
#   libgbm1 libgl1 libgl1-mesa-dri libglapi-mesa libgles1 libgles2
#   libglvnd-core-dev libglvnd-dev libglvnd0 libglx-mesa0 libglx0 libllvm7
#   libopengl0 libsensors-config libsensors5 libwayland-client0
#   libwayland-server0 libx11-xcb-dev libx11-xcb1 libxcb-dri2-0
#   libxcb-dri2-0-dev libxcb-dri3-0 libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev
#   libxcb-present-dev libxcb-present0 libxcb-randr0 libxcb-randr0-dev
#   libxcb-shape0 libxcb-shape0-dev libxcb-sync-dev libxcb-sync1 libxcb-xfixes0
#   libxcb-xfixes0-dev libxdamage-dev libxdamage1 libxfixes-dev libxfixes3
#   libxshmfence-dev libxshmfence1 libxxf86vm-dev libxxf86vm1 mesa-common-dev
#   x11proto-damage-dev x11proto-fixes-dev x11proto-xf86vidmode-dev
# Suggested packages:
#   lm-sensors
# The following NEW packages will be installed:
#   libdrm-amdgpu1 libdrm-common libdrm-dev libdrm-etnaviv1 libdrm-freedreno1
#   libdrm-nouveau2 libdrm-radeon1 libdrm-tegra0 libdrm2 libegl-mesa0 libegl1
#   libgbm1 libgl1 libgl1-mesa-dev libgl1-mesa-dri libglapi-mesa libgles1
#   libgles2 libglvnd-core-dev libglvnd-dev libglvnd0 libglx-mesa0 libglx0
#   libllvm7 libopengl0 libsensors-config libsensors5 libwayland-client0
#   libwayland-server0 libx11-xcb-dev libx11-xcb1 libxcb-dri2-0
#   libxcb-dri2-0-dev libxcb-dri3-0 libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev
#   libxcb-present-dev libxcb-present0 libxcb-randr0 libxcb-randr0-dev
#   libxcb-shape0 libxcb-shape0-dev libxcb-sync-dev libxcb-sync1 libxcb-xfixes0
#   libxcb-xfixes0-dev libxdamage-dev libxdamage1 libxfixes-dev libxfixes3
#   libxshmfence-dev libxshmfence1 libxxf86vm-dev libxxf86vm1 mesa-common-dev
#   x11proto-damage-dev x11proto-fixes-dev x11proto-xf86vidmode-dev
# 0 upgraded, 59 newly installed, 0 to remove and 0 not upgraded.
# Need to get 19.8 MB of archives.
# After this operation, 260 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main arm64 libdrm-common all 2.4.97-1 [13.8 kB]
# Get:2 http://deb.debian.org/debian buster/main arm64 libdrm2 arm64 2.4.97-1 [39.5 kB]
# Get:3 http://deb.debian.org/debian buster/main arm64 libdrm-amdgpu1 arm64 2.4.97-1 [26.6 kB]
# Get:4 http://deb.debian.org/debian buster/main arm64 libdrm-radeon1 arm64 2.4.97-1 [30.0 kB]
# Get:5 http://deb.debian.org/debian buster/main arm64 libdrm-nouveau2 arm64 2.4.97-1 [25.5 kB]
# Get:6 http://deb.debian.org/debian buster/main arm64 libdrm-freedreno1 arm64 2.4.97-1 [27.8 kB]
# Get:7 http://deb.debian.org/debian buster/main arm64 libdrm-tegra0 arm64 2.4.97-1 [15.8 kB]
# Get:8 http://deb.debian.org/debian buster/main arm64 libdrm-etnaviv1 arm64 2.4.97-1 [21.0 kB]
# Get:9 http://deb.debian.org/debian buster/main arm64 libdrm-dev arm64 2.4.97-1 [135 kB]
# Get:10 http://deb.debian.org/debian buster/main arm64 libwayland-server0 arm64 1.16.0-1 [31.8 kB]
# Get:11 http://deb.debian.org/debian buster/main arm64 libgbm1 arm64 18.3.6-2+deb10u1 [67.1 kB]
# Get:12 http://deb.debian.org/debian buster/main arm64 libglapi-mesa arm64 18.3.6-2+deb10u1 [74.8 kB]
# Get:13 http://deb.debian.org/debian buster/main arm64 libwayland-client0 arm64 1.16.0-1 [25.9 kB]
# Get:14 http://deb.debian.org/debian buster/main arm64 libx11-xcb1 arm64 2:1.6.7-1+deb10u1 [190 kB]
# Get:15 http://deb.debian.org/debian buster/main arm64 libxcb-dri2-0 arm64 1.13.1-2 [101 kB]
# Get:16 http://deb.debian.org/debian buster/main arm64 libxcb-dri3-0 arm64 1.13.1-2 [100 kB]
# Get:17 http://deb.debian.org/debian buster/main arm64 libxcb-present0 arm64 1.13.1-2 [99.1 kB]
# Get:18 http://deb.debian.org/debian buster/main arm64 libxcb-sync1 arm64 1.13.1-2 [102 kB]
# Get:19 http://deb.debian.org/debian buster/main arm64 libxcb-xfixes0 arm64 1.13.1-2 [103 kB]
# Get:20 http://deb.debian.org/debian buster/main arm64 libxshmfence1 arm64 1.3-1 [8712 B]
# Get:21 http://deb.debian.org/debian buster/main arm64 libegl-mesa0 arm64 18.3.6-2+deb10u1 [130 kB]
# Get:22 http://deb.debian.org/debian buster/main arm64 mesa-common-dev arm64 18.3.6-2+deb10u1 [611 kB]
# Get:23 http://deb.debian.org/debian buster/main arm64 libglvnd0 arm64 1.1.0-1 [42.4 kB]
# Get:24 http://deb.debian.org/debian buster/main arm64 libglvnd-core-dev arm64 1.1.0-1 [13.2 kB]
# Get:25 http://deb.debian.org/debian buster/main arm64 libegl1 arm64 1.1.0-1 [32.8 kB]
# Get:26 http://deb.debian.org/debian buster/main arm64 libgles1 arm64 1.1.0-1 [14.3 kB]
# Get:27 http://deb.debian.org/debian buster/main arm64 libgles2 arm64 1.1.0-1 [19.8 kB]
# Get:28 http://deb.debian.org/debian buster/main arm64 libxcb-glx0 arm64 1.13.1-2 [116 kB]
# Get:29 http://deb.debian.org/debian buster/main arm64 libxfixes3 arm64 1:5.0.3-1 [21.0 kB]
# Get:30 http://deb.debian.org/debian buster/main arm64 libxdamage1 arm64 1:1.1.4-3+b3 [14.8 kB]
# Get:31 http://deb.debian.org/debian buster/main arm64 libxxf86vm1 arm64 1:1.1.4-1+b2 [20.1 kB]
# Get:32 http://deb.debian.org/debian buster/main arm64 libllvm7 arm64 1:7.0.1-8+deb10u2 [10.8 MB]
# Get:33 http://deb.debian.org/debian buster/main arm64 libsensors-config all 1:3.5.0-3 [31.6 kB]
# Get:34 http://deb.debian.org/debian buster/main arm64 libsensors5 arm64 1:3.5.0-3 [51.8 kB]
# Get:35 http://deb.debian.org/debian buster/main arm64 libgl1-mesa-dri arm64 18.3.6-2+deb10u1 [4910 kB]
# Get:36 http://deb.debian.org/debian buster/main arm64 libglx-mesa0 arm64 18.3.6-2+deb10u1 [180 kB]
# Get:37 http://deb.debian.org/debian buster/main arm64 libglx0 arm64 1.1.0-1 [29.0 kB]
# Get:38 http://deb.debian.org/debian buster/main arm64 libgl1 arm64 1.1.0-1 [92.5 kB]
# Get:39 http://deb.debian.org/debian buster/main arm64 libopengl0 arm64 1.1.0-1 [34.4 kB]
# Get:40 http://deb.debian.org/debian buster/main arm64 libglvnd-dev arm64 1.1.0-1 [5128 B]
# Get:41 http://deb.debian.org/debian buster/main arm64 libx11-xcb-dev arm64 2:1.6.7-1+deb10u1 [192 kB]
# Get:42 http://deb.debian.org/debian buster/main arm64 libxcb-dri3-dev arm64 1.13.1-2 [101 kB]
# Get:43 http://deb.debian.org/debian buster/main arm64 libxcb-randr0 arm64 1.13.1-2 [110 kB]
# Get:44 http://deb.debian.org/debian buster/main arm64 libxcb-randr0-dev arm64 1.13.1-2 [115 kB]
# Get:45 http://deb.debian.org/debian buster/main arm64 libxcb-shape0 arm64 1.13.1-2 [99.6 kB]
# Get:46 http://deb.debian.org/debian buster/main arm64 libxcb-shape0-dev arm64 1.13.1-2 [101 kB]
# Get:47 http://deb.debian.org/debian buster/main arm64 libxcb-xfixes0-dev arm64 1.13.1-2 [106 kB]
# Get:48 http://deb.debian.org/debian buster/main arm64 libxcb-sync-dev arm64 1.13.1-2 [105 kB]
# Get:49 http://deb.debian.org/debian buster/main arm64 libxcb-present-dev arm64 1.13.1-2 [101 kB]
# Get:50 http://deb.debian.org/debian buster/main arm64 libxshmfence-dev arm64 1.3-1 [8212 B]
# Get:51 http://deb.debian.org/debian buster/main arm64 libxcb-dri2-0-dev arm64 1.13.1-2 [102 kB]
# Get:52 http://deb.debian.org/debian buster/main arm64 libxcb-glx0-dev arm64 1.13.1-2 [122 kB]
# Get:53 http://deb.debian.org/debian buster/main arm64 x11proto-fixes-dev all 1:2018.4-4 [3140 B]
# Get:54 http://deb.debian.org/debian buster/main arm64 libxfixes-dev arm64 1:5.0.3-1 [23.2 kB]
# Get:55 http://deb.debian.org/debian buster/main arm64 x11proto-damage-dev all 1:2018.4-4 [3140 B]
# Get:56 http://deb.debian.org/debian buster/main arm64 libxdamage-dev arm64 1:1.1.4-3+b3 [14.8 kB]
# Get:57 http://deb.debian.org/debian buster/main arm64 x11proto-xf86vidmode-dev all 2018.4-4 [3140 B]
# Get:58 http://deb.debian.org/debian buster/main arm64 libxxf86vm-dev arm64 1:1.1.4-1+b2 [25.1 kB]
# Get:59 http://deb.debian.org/debian buster/main arm64 libgl1-mesa-dev arm64 18.3.6-2+deb10u1 [48.0 kB]
# Fetched 19.8 MB in 1s (16.2 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libdrm-common.
# (Reading database ... 34222 files and directories currently installed.)
# Preparing to unpack .../00-libdrm-common_2.4.97-1_all.deb ...
# Unpacking libdrm-common (2.4.97-1) ...
# Selecting previously unselected package libdrm2:arm64.
# Preparing to unpack .../01-libdrm2_2.4.97-1_arm64.deb ...
# Unpacking libdrm2:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-amdgpu1:arm64.
# Preparing to unpack .../02-libdrm-amdgpu1_2.4.97-1_arm64.deb ...
# Unpacking libdrm-amdgpu1:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-radeon1:arm64.
# Preparing to unpack .../03-libdrm-radeon1_2.4.97-1_arm64.deb ...
# Unpacking libdrm-radeon1:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-nouveau2:arm64.
# Preparing to unpack .../04-libdrm-nouveau2_2.4.97-1_arm64.deb ...
# Unpacking libdrm-nouveau2:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-freedreno1:arm64.
# Preparing to unpack .../05-libdrm-freedreno1_2.4.97-1_arm64.deb ...
# Unpacking libdrm-freedreno1:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-tegra0:arm64.
# Preparing to unpack .../06-libdrm-tegra0_2.4.97-1_arm64.deb ...
# Unpacking libdrm-tegra0:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-etnaviv1:arm64.
# Preparing to unpack .../07-libdrm-etnaviv1_2.4.97-1_arm64.deb ...
# Unpacking libdrm-etnaviv1:arm64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-dev:arm64.
# Preparing to unpack .../08-libdrm-dev_2.4.97-1_arm64.deb ...
# Unpacking libdrm-dev:arm64 (2.4.97-1) ...
# Selecting previously unselected package libwayland-server0:arm64.
# Preparing to unpack .../09-libwayland-server0_1.16.0-1_arm64.deb ...
# Unpacking libwayland-server0:arm64 (1.16.0-1) ...
# Selecting previously unselected package libgbm1:arm64.
# Preparing to unpack .../10-libgbm1_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking libgbm1:arm64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglapi-mesa:arm64.
# Preparing to unpack .../11-libglapi-mesa_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking libglapi-mesa:arm64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libwayland-client0:arm64.
# Preparing to unpack .../12-libwayland-client0_1.16.0-1_arm64.deb ...
# Unpacking libwayland-client0:arm64 (1.16.0-1) ...
# Selecting previously unselected package libx11-xcb1:arm64.
# Preparing to unpack .../13-libx11-xcb1_2%3a1.6.7-1+deb10u1_arm64.deb ...
# Unpacking libx11-xcb1:arm64 (2:1.6.7-1+deb10u1) ...
# Selecting previously unselected package libxcb-dri2-0:arm64.
# Preparing to unpack .../14-libxcb-dri2-0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-dri2-0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-dri3-0:arm64.
# Preparing to unpack .../15-libxcb-dri3-0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-dri3-0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-present0:arm64.
# Preparing to unpack .../16-libxcb-present0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-present0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-sync1:arm64.
# Preparing to unpack .../17-libxcb-sync1_1.13.1-2_arm64.deb ...
# Unpacking libxcb-sync1:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-xfixes0:arm64.
# Preparing to unpack .../18-libxcb-xfixes0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-xfixes0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxshmfence1:arm64.
# Preparing to unpack .../19-libxshmfence1_1.3-1_arm64.deb ...
# Unpacking libxshmfence1:arm64 (1.3-1) ...
# Selecting previously unselected package libegl-mesa0:arm64.
# Preparing to unpack .../20-libegl-mesa0_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking libegl-mesa0:arm64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package mesa-common-dev:arm64.
# Preparing to unpack .../21-mesa-common-dev_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking mesa-common-dev:arm64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglvnd0:arm64.
# Preparing to unpack .../22-libglvnd0_1.1.0-1_arm64.deb ...
# Unpacking libglvnd0:arm64 (1.1.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:arm64.
# Preparing to unpack .../23-libglvnd-core-dev_1.1.0-1_arm64.deb ...
# Unpacking libglvnd-core-dev:arm64 (1.1.0-1) ...
# Selecting previously unselected package libegl1:arm64.
# Preparing to unpack .../24-libegl1_1.1.0-1_arm64.deb ...
# Unpacking libegl1:arm64 (1.1.0-1) ...
# Selecting previously unselected package libgles1:arm64.
# Preparing to unpack .../25-libgles1_1.1.0-1_arm64.deb ...
# Unpacking libgles1:arm64 (1.1.0-1) ...
# Selecting previously unselected package libgles2:arm64.
# Preparing to unpack .../26-libgles2_1.1.0-1_arm64.deb ...
# Unpacking libgles2:arm64 (1.1.0-1) ...
# Selecting previously unselected package libxcb-glx0:arm64.
# Preparing to unpack .../27-libxcb-glx0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-glx0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxfixes3:arm64.
# Preparing to unpack .../28-libxfixes3_1%3a5.0.3-1_arm64.deb ...
# Unpacking libxfixes3:arm64 (1:5.0.3-1) ...
# Selecting previously unselected package libxdamage1:arm64.
# Preparing to unpack .../29-libxdamage1_1%3a1.1.4-3+b3_arm64.deb ...
# Unpacking libxdamage1:arm64 (1:1.1.4-3+b3) ...
# Selecting previously unselected package libxxf86vm1:arm64.
# Preparing to unpack .../30-libxxf86vm1_1%3a1.1.4-1+b2_arm64.deb ...
# Unpacking libxxf86vm1:arm64 (1:1.1.4-1+b2) ...
# Selecting previously unselected package libllvm7:arm64.
# Preparing to unpack .../31-libllvm7_1%3a7.0.1-8+deb10u2_arm64.deb ...
# Unpacking libllvm7:arm64 (1:7.0.1-8+deb10u2) ...
# Selecting previously unselected package libsensors-config.
# Preparing to unpack .../32-libsensors-config_1%3a3.5.0-3_all.deb ...
# Unpacking libsensors-config (1:3.5.0-3) ...
# Selecting previously unselected package libsensors5:arm64.
# Preparing to unpack .../33-libsensors5_1%3a3.5.0-3_arm64.deb ...
# Unpacking libsensors5:arm64 (1:3.5.0-3) ...
# Selecting previously unselected package libgl1-mesa-dri:arm64.
# Preparing to unpack .../34-libgl1-mesa-dri_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking libgl1-mesa-dri:arm64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglx-mesa0:arm64.
# Preparing to unpack .../35-libglx-mesa0_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking libglx-mesa0:arm64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglx0:arm64.
# Preparing to unpack .../36-libglx0_1.1.0-1_arm64.deb ...
# Unpacking libglx0:arm64 (1.1.0-1) ...
# Selecting previously unselected package libgl1:arm64.
# Preparing to unpack .../37-libgl1_1.1.0-1_arm64.deb ...
# Unpacking libgl1:arm64 (1.1.0-1) ...
# Selecting previously unselected package libopengl0:arm64.
# Preparing to unpack .../38-libopengl0_1.1.0-1_arm64.deb ...
# Unpacking libopengl0:arm64 (1.1.0-1) ...
# Selecting previously unselected package libglvnd-dev:arm64.
# Preparing to unpack .../39-libglvnd-dev_1.1.0-1_arm64.deb ...
# Unpacking libglvnd-dev:arm64 (1.1.0-1) ...
# Selecting previously unselected package libx11-xcb-dev:arm64.
# Preparing to unpack .../40-libx11-xcb-dev_2%3a1.6.7-1+deb10u1_arm64.deb ...
# Unpacking libx11-xcb-dev:arm64 (2:1.6.7-1+deb10u1) ...
# Selecting previously unselected package libxcb-dri3-dev:arm64.
# Preparing to unpack .../41-libxcb-dri3-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-dri3-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-randr0:arm64.
# Preparing to unpack .../42-libxcb-randr0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-randr0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-randr0-dev:arm64.
# Preparing to unpack .../43-libxcb-randr0-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-randr0-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-shape0:arm64.
# Preparing to unpack .../44-libxcb-shape0_1.13.1-2_arm64.deb ...
# Unpacking libxcb-shape0:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-shape0-dev:arm64.
# Preparing to unpack .../45-libxcb-shape0-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-shape0-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-xfixes0-dev:arm64.
# Preparing to unpack .../46-libxcb-xfixes0-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-xfixes0-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-sync-dev:arm64.
# Preparing to unpack .../47-libxcb-sync-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-sync-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-present-dev:arm64.
# Preparing to unpack .../48-libxcb-present-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-present-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxshmfence-dev:arm64.
# Preparing to unpack .../49-libxshmfence-dev_1.3-1_arm64.deb ...
# Unpacking libxshmfence-dev:arm64 (1.3-1) ...
# Selecting previously unselected package libxcb-dri2-0-dev:arm64.
# Preparing to unpack .../50-libxcb-dri2-0-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-dri2-0-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-glx0-dev:arm64.
# Preparing to unpack .../51-libxcb-glx0-dev_1.13.1-2_arm64.deb ...
# Unpacking libxcb-glx0-dev:arm64 (1.13.1-2) ...
# Selecting previously unselected package x11proto-fixes-dev.
# Preparing to unpack .../52-x11proto-fixes-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-fixes-dev (1:2018.4-4) ...
# Selecting previously unselected package libxfixes-dev:arm64.
# Preparing to unpack .../53-libxfixes-dev_1%3a5.0.3-1_arm64.deb ...
# Unpacking libxfixes-dev:arm64 (1:5.0.3-1) ...
# Selecting previously unselected package x11proto-damage-dev.
# Preparing to unpack .../54-x11proto-damage-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-damage-dev (1:2018.4-4) ...
# Selecting previously unselected package libxdamage-dev:arm64.
# Preparing to unpack .../55-libxdamage-dev_1%3a1.1.4-3+b3_arm64.deb ...
# Unpacking libxdamage-dev:arm64 (1:1.1.4-3+b3) ...
# Selecting previously unselected package x11proto-xf86vidmode-dev.
# Preparing to unpack .../56-x11proto-xf86vidmode-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xf86vidmode-dev (2018.4-4) ...
# Selecting previously unselected package libxxf86vm-dev:arm64.
# Preparing to unpack .../57-libxxf86vm-dev_1%3a1.1.4-1+b2_arm64.deb ...
# Unpacking libxxf86vm-dev:arm64 (1:1.1.4-1+b2) ...
# Selecting previously unselected package libgl1-mesa-dev:arm64.
# Preparing to unpack .../58-libgl1-mesa-dev_18.3.6-2+deb10u1_arm64.deb ...
# Unpacking libgl1-mesa-dev:arm64 (18.3.6-2+deb10u1) ...
# Setting up libxcb-dri3-0:arm64 (1.13.1-2) ...
# Setting up libwayland-server0:arm64 (1.16.0-1) ...
# Setting up libx11-xcb1:arm64 (2:1.6.7-1+deb10u1) ...
# Setting up libx11-xcb-dev:arm64 (2:1.6.7-1+deb10u1) ...
# Setting up libxcb-xfixes0:arm64 (1.13.1-2) ...
# Setting up libglvnd-core-dev:arm64 (1.1.0-1) ...
# Setting up libglvnd0:arm64 (1.1.0-1) ...
# Setting up libxcb-glx0:arm64 (1.13.1-2) ...
# Setting up libxcb-shape0:arm64 (1.13.1-2) ...
# Setting up libsensors-config (1:3.5.0-3) ...
# Setting up libxcb-dri3-dev:arm64 (1.13.1-2) ...
# Setting up libopengl0:arm64 (1.1.0-1) ...
# Setting up libxxf86vm1:arm64 (1:1.1.4-1+b2) ...
# Setting up libxcb-present0:arm64 (1.13.1-2) ...
# Setting up x11proto-damage-dev (1:2018.4-4) ...
# Setting up libgles2:arm64 (1.1.0-1) ...
# Setting up libxfixes3:arm64 (1:5.0.3-1) ...
# Setting up libxcb-sync1:arm64 (1.13.1-2) ...
# Setting up libgles1:arm64 (1.1.0-1) ...
# Setting up libxcb-glx0-dev:arm64 (1.13.1-2) ...
# Setting up libsensors5:arm64 (1:3.5.0-3) ...
# Setting up libglapi-mesa:arm64 (18.3.6-2+deb10u1) ...
# Setting up libxcb-shape0-dev:arm64 (1.13.1-2) ...
# Setting up libxcb-dri2-0:arm64 (1.13.1-2) ...
# Setting up x11proto-xf86vidmode-dev (2018.4-4) ...
# Setting up libxshmfence1:arm64 (1.3-1) ...
# Setting up libxcb-randr0:arm64 (1.13.1-2) ...
# Setting up libllvm7:arm64 (1:7.0.1-8+deb10u2) ...
# Setting up libxcb-sync-dev:arm64 (1.13.1-2) ...
# Setting up libxcb-xfixes0-dev:arm64 (1.13.1-2) ...
# Setting up x11proto-fixes-dev (1:2018.4-4) ...
# Setting up libdrm-common (2.4.97-1) ...
# Setting up libwayland-client0:arm64 (1.16.0-1) ...
# Setting up libxdamage1:arm64 (1:1.1.4-3+b3) ...
# Setting up libxshmfence-dev:arm64 (1.3-1) ...
# Setting up libxxf86vm-dev:arm64 (1:1.1.4-1+b2) ...
# Setting up libxfixes-dev:arm64 (1:5.0.3-1) ...
# Setting up libxcb-dri2-0-dev:arm64 (1.13.1-2) ...
# Setting up libxcb-randr0-dev:arm64 (1.13.1-2) ...
# Setting up libxcb-present-dev:arm64 (1.13.1-2) ...
# Setting up libdrm2:arm64 (2.4.97-1) ...
# Setting up libdrm-amdgpu1:arm64 (2.4.97-1) ...
# Setting up libxdamage-dev:arm64 (1:1.1.4-3+b3) ...
# Setting up libdrm-nouveau2:arm64 (2.4.97-1) ...
# Setting up libdrm-etnaviv1:arm64 (2.4.97-1) ...
# Setting up libgbm1:arm64 (18.3.6-2+deb10u1) ...
# Setting up libdrm-radeon1:arm64 (2.4.97-1) ...
# Setting up libgl1-mesa-dri:arm64 (18.3.6-2+deb10u1) ...
# Setting up libegl-mesa0:arm64 (18.3.6-2+deb10u1) ...
# Setting up libdrm-freedreno1:arm64 (2.4.97-1) ...
# Setting up libdrm-tegra0:arm64 (2.4.97-1) ...
# Setting up libegl1:arm64 (1.1.0-1) ...
# Setting up libdrm-dev:arm64 (2.4.97-1) ...
# Setting up libglx-mesa0:arm64 (18.3.6-2+deb10u1) ...
# Setting up libglx0:arm64 (1.1.0-1) ...
# Setting up libgl1:arm64 (1.1.0-1) ...
# Setting up mesa-common-dev:arm64 (18.3.6-2+deb10u1) ...
# Setting up libglvnd-dev:arm64 (1.1.0-1) ...
# Setting up libgl1-mesa-dev:arm64 (18.3.6-2+deb10u1) ...
# Processing triggers for libc-bin (2.28-10) ...

# %% [markdown]
# ## 必要ライブラリのインストール

# %%
# !pip install numpy matplotlib opencv-python sklearn
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (1.20.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/site-packages (4.5.1.48)
# Requirement already satisfied: sklearn in /root/.local/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.0.1)

# %% [markdown]
# ## ライブラリのインポート

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.9/site-packages (from opencv-python) (1.20.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## 画像の読み込み、表示
#
# ローカルにある画像はcv2.imread で読み込みができますが、これをmatplotlibで表示すると、変な色になります。
#
# cv2で読み込むとBGRの順番になりますが、matplotlibではRGBとして扱われるからです。

# %%
# 画像の読み込み
img = cv2.imread("../assets/imori.jpg")

# 画像の表示
plt.imshow(img)
plt.show()

# %% [markdown]
# 　なので、画像のBGRの反転が必要になります。

# %%
img = img[..., ::-1]
plt.imshow(img)
plt.show()

# %% [markdown]
# つまり、opencvで読み込むならBGRをRGBに反転する癖をつけましょう

# %%
img = cv2.imread("../assets/imori.jpg")
img = img[..., ::-1]

plt.imshow(img)
plt.show()

# %% [markdown]
# ## URLの画像を読み込む
#
# sklearnのio.imreadはURLでの指定が可能です。imori_128x128.pngやimori_256x256.pngはネット公開されているので、URL指定が可能です。
# しかもこっちはRGBの順に読み込まれるので、opencvと違い反転の必要がありません。
#
# GoogleColabなどを使用する人は、こっちの方が画像をダウンロードする手間がないので楽です!

# %%
from skimage import io

img = io.imread('https://yoyoyo-yo.github.io/Gasyori100knock/assets/imori_256x256.png')

plt.imshow(img)
plt.show()

# %% [markdown]
# ## 画像データの基礎知識
#
# - データの中身は0 ~ 255の整数256段階
# - 基本カラー画像はRGBの組み合わせで表現される
#
# 画像データの中身は0から255の256 $(= 2 ^ 8)$段階で、これは8ビットに由来する。値が大きいほど色が強く現れるということになる。

# %%
print('min =', img.min())
print('max =', img.max())
# Out:
# min = 5
# max = 255

# %% [markdown]
# 色はRGB (Red, Green, Blue)の３色を組み合わせて表現されている。この数はチャンネルと呼ばれる。それぞれ抜き出してみる。
# ちなみにグレースケールと呼ばれる画像は、RGBに重みをつけて1チャンネルにしたものになるので、チャンネル数は1となる。

# %%
r = img[..., 0]
g = img[..., 1]
b = img[..., 2]
plt.subplot(1, 3, 1)
plt.title('R')
plt.imshow(r, cmap='gray')
plt.subplot(1, 3, 2)
plt.title('G')
plt.imshow(g, cmap='gray')
plt.subplot(1, 3, 3)
plt.title('B')
plt.imshow(b, cmap='gray')
plt.show()

# %% [markdown]
# ## 画像のサイズ
#
# shapeには（縦サイズ、横サイズ、チャンネルサイズ）が入っています

# %%
img.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## 画像のデータ型
#
# 型をとるには、img.dtypeを使用します。 uint8とは符号なしintで8ビットを意味します。画像はRGB成分がそれぞれ通常0から255の256段階で表現されます。 例えば、赤のピクセルは(R,G,B) = (255, 0, 0)、白は(R,G,B) = (255, 255, 255)です。 画像にする時は必ずこの型にしないと画像がおかしくなってしまいます。（あとで説明します。）

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# 例えば、imgの型をfloat32にしてみます。 これはastype()を使えばできます。

# %%
_img = img.astype(np.float32)
_img.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ただし、float型は表示されない。

# %%
plt.imshow(_img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# たplt.subplot(1, 3, 1)だし、float型の時は、$[0, 1]$の範囲の値になっていれば表示できる。なので、255で割ってみると表示できる

# %%
_img /= 255
plt.imshow(_img)
plt.show()

# %% [markdown]
# 一般的に画像を操作する時は、以下の方法がおすすめ
#
# 1. cv2.imread, io.imreadで読み込む
# 2. 型を一度np.float32など小数点型に変換する
# 3. 画像をいじる
# 4. 画素が0未満のものは0, 255を超えたものは255に直す。（超重要）
# 5. 型をnp.uint8に変換して表示・保存する この手順にすることをおすすめします。

# %% [markdown]
# ## 画像のコピー
#
# 画像を別変数にコピーしたい時はcopy()を使いましょう。単純に img2 = img とすると、画像のアドレスが保存されるのでimg2をいじるとimgにも反映されてしまします。特別な利用がない場合は、copy()で画像をコピーしましょう。

# %%
img2 = img.copy()

# %% [markdown]
# ## 画素をいじる
#
# 画像の操作法はnumpyとほとんど同じ。
#
# 例えば、x=30、y=20の画素値をいじりたい時は、こうする。 画素値はBGRの順に並んでいます。array()とはnumpy形式になっていることを意味する。つまり、opencv, sklearnはnumpyをラッパーしている。

# %%
img[20, 30]
# Out:
# array([ 58,  75, 121], dtype=uint8)

# %% [markdown]
# さらに、x=30、y=20、のG成分をとる時はこうします。

# %%
img[20, 30, 1]
# Out:
# 75

# %% [markdown]
# ここから、numpyの本題になる。
#
# numpyにはスライスという機能がある。 これはある値v1からある値v2までの全ての要素にアクセスできることを意味する。
#
# 例えば、y=20, x=[30, 32]までを見る時はこうする。 30:33とすれば行列のまま取り出せる。a:bとすることで、a<= v < bの値にアクセスできる。 ちなみに :30とすれば [0, 30]、30:とすれば[30, 最後]までを取り出せる。

# %%
img[20, 30:33]
# Out:
# array([[ 58,  75, 121],
#        [ 43,  70, 113],
#        [ 47,  72, 103]], dtype=uint8)

# %% [markdown]
# 例えば画像の左上(x=[0, 50], y = [0, 50])を黒にするには、こんな感じでできる。

# %%
img2 = img.copy()
img2[:50, :50] = 0
plt.imshow(img2)
plt.show()

# %% [markdown]
# 次に先程の　4. 画素が0未満のものは0, 255を超えたものは255に直す。　に関して説明します。
#
# 例えば、画像を一度 float32型にして、一部分のB成分を260という値に変えてみます。 uint8型は[0, 255] の範囲しか取り得ないので、これをuint8型に直すとこんな風になります。 イモリの顔の一部分が黄色くなってしまっています。
#
# これは、260をuint8型に直すと260 - 256 が起きて、B=4となってしまうためです。 これが原因で画素値がおかしくなることが多々起きてしまいます。 なので、4の操作が必要となります。

# %%
img2 = img.copy().astype(np.float32)
img2[60:160, 60:160, 2] = 2
img2 = img2.astype(np.uint8)
plt.imshow(img2)
plt.show()

# %%
img2[60, 60, 2]
# Out:
# 2

# %% [markdown]
# ## 画像の保存
#
# 画像の保存にはcv2.imwrite()または、plt.savefig()などを使いましょう

# %%
cv2.imwrite('sample.png', img2)
# Out:
# True

# %%
plt.imshow(img)
plt.savefig('sample.png')

# %% [markdown]
# ## 練習
#
# 画像の左半分上のRとBを入れ替えて表示してみましょう。

# %%
img3 = img.copy()
h, w, c = img3.shape
img3[: h // 2, : w // 2] = img3[: h // 2, : w // 2, ::-1]
plt.imshow(img3)
plt.show()

# %%
img3[:124, :123] = img3[:124, :123, ::-1]


plt.imshow(img3)

# %% [markdown]
# 以上でチュートリアルは終了です。あとはばんばん問題を解いて下さい！！！！
